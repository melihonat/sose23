# %% [markdown]
# ## Praktische Aufgaben – Blatt 6

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import sklearn.datasets
import sklearn.model_selection
import sklearn.metrics

# %%
import hmmlearn.hmm as hmm
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Aufgabe 1: SSVEP BCI
#
# Anliegend findet ihr vier EEG Aufnahmen als CSV gespeichert. Diese stammen aus einem Brain-Computer-Interface (BCI) Experiment, welches mit einem Steady State Visual Evoked Potential (SSVEP) arbeitet. Das heißt, es flackern auf einem Bildschirm vier Kästchen jeweils mit einer eigenen Frequenz und der/die Nutzer:in fokussiert sich auf eines um eine Aktion auszuführen. Die Frequenz findet sich dann im EEG des Okzipitallappens wieder.
#
# Die Daten wurden mit 500 Hz aufgezeichnet und stammen von den drei Elektroden "O1", "Oz", "O2". Die vier Kästchen flackerten mit 4, 6, 10 und 15 Hz.

# %%
channels = ["O1", "Oz", "O2"]

a = pd.read_csv('a.csv', names=channels, sep=' ')
b = pd.read_csv('b.csv', names=channels, sep=' ')
c = pd.read_csv('c.csv', names=channels, sep=' ')
d = pd.read_csv('d.csv', names=channels, sep=' ')

a_values = a.values
b_values = b.values
c_values = c.values
d_values = d.values

# %% [markdown]
# **1.** Plottet Aufnahme a als Linienplot.

# %%
# YOUR CODE HERE
times = np.arange(len(a)) / 500.0

sns.lineplot(x=times, y=a["O1"], label="O1")
sns.lineplot(x=times, y=a["Oz"], label="Oz")
sns.lineplot(x=times, y=a["O2"], label="O2")
plt.xlabel("Zeit in s")
plt.ylabel("EEG-Wert")
# Out:
# Text(0, 0.5, 'EEG-Wert')

# %% [markdown]
# **2.** Könnt ihr basierend auf diesem Plot etwas erkennen, welche Frequenz der/die Nutzer:in fokussiert hat?

# %% [markdown]
# Basierend auf den im Plot abgetragenen EEG-Werten lässt sich keine Entscheidung treffen, auf welche Frequenz sich von dem/der Nutzer:in fokussiert wurde. Dafür müsste das Signal zunächst weiterverarbeitet werden, beispielsweise durch Anwendung einer FFT.

# %% [markdown]
# **3.** Wir möchten nun die Powerspektren pro Kanal und Aufnahme darstellen. Implementiert dafür zunächst die Funktion `calc_powerspektrum`; `channel` entspricht hierbei einem Kanal, bspw. `a_values[:, 0]`.

# %%
def calc_powerspektrum(channel):
    # Berechnet die absolute Energie (np.fft.rfft kann hier helfen)
    abs_spec = np.array([])
    
    # YOUR CODE HERE
    abs_spec = np.abs(np.fft.rfft(channel))

    # Berechnet die Frequenzbins (np.fft.rfftfreq kann hier helfen) 
    freqs = np.array([])
    
    # YOUR CODE HERE
    freqs = np.fft.rfftfreq(len(channel), d=1/500.0)
    
    # Behaltet nur diejenigen Frequenzen zwischen 3 und 40 Hz
    # YOUR CODE HERE
    freqs = freqs[(freqs >= 3) & (freqs <= 40)]
    abs_spec = abs_spec[:len(freqs)]
    
    # Gebt als ersten Rückgabewert die Frequenzen und als zweiten die zugehörige Energie zurück
    # YOUR CODE HERE
    return freqs, abs_spec

# %% [markdown]
# **4.** Plottet nun die Powerspektren pro Kanal und Aufnahme.
#
# _Hinweis_: die `for`-Schleife dient der Hilfe. Ihr dürft diese auch durch eure eigene Implementierung ersetzen, wenn ihr möchtet.

# %%
for trial in [a_values, b_values, c_values, d_values]:
    # YOUR CODE HERE
    #for channel_number, channel_name in enumerate(channels):
     #   channel_data = trial[:, channel_number]
      #  freqs, powerspec = calc_powerspektrum(channel_data)
       # plt.plot(freqs, powerspec, label=channel_name)
        
    spec = calc_powerspektrum(trial[:,0])
    plt.plot(spec[0], spec[1])
    
    spec = calc_powerspektrum(trial[:,1])
    plt.plot(spec[0], spec[1])
    
    spec = calc_powerspektrum(trial[:,2])
    plt.plot(spec[0], spec[1])
        
    plt.xlabel("Frequenz in Hz")
    plt.ylabel("Energie")
    plt.xlim(0,42)
    plt.ylim(0,4000)
    plt.legend(["O1","Oz","O2"])
    plt.show()

# %% [markdown]
# Referenz für möglichen Plot für a.csv aus Aufgabenteil 4.
#
# <img src="a.png" style="width: 50%">

# %% [markdown]
# **5.** Basierend auf den Plots, auf welche Frequenz hat sich der/die Nutzer:in in `a`, `b`, `c` und `d` jeweils fokussiert?

# %% [markdown]
# Bei ```a``` ist es schwer zu sagen, weil der Peak nicht exakt bei 15 Hz ist, aber da das die nächste Frequenz ist, ist das am wahrscheinlichsten. Bei ```b``` ist es 50/50 zwischen 10 und 15Hz. Bei ```c``` sieht es so aus, als hätte sich der/die Nutzer:in auf alle 4 Frequenzen gleichzeitig fokussieren wollen, aber der Peak bei 6Hz ist am höchsten. Bei ```d``` ist mit hoher Wahrscheinlichkeit 10Hz der Fokus gewesen.

# %% [markdown]
# **6.** Woran erkennt ihr die fokussierten Frequenzen?

# %% [markdown]
# Wie bereits beantwortet an den hervorstechendsten Peaks in den Powerspektrum-Plots. Diese muss man dan mit den bekannten flackernden Frequenzen (4, 6, 10, und 15Hz) abgleichen und bestimmen, welche der Frequenzen den Peaks am nächsten kommt.

# %% [markdown]
# ### 2. Aufgabe: Evaluation
#
# Im Folgenden möchten wir zwei Klassifikatoren auswerten und auf einem Datensatz vergleichen. Wir nutzen dazu den Breast Cancer Datensatz (https://scikit-learn.org/stable/datasets/toy_dataset.html#breast-cancer-dataset) sowie eine SVM und ein KNN.

# %%
breast_cancer = sklearn.datasets.load_breast_cancer()

# %% [markdown]
# **1.** Teilt den Datensatz dafür zuerst in Trainings- und Testset mit einem 80% zu 20% Verhältnis.

# %%
train_X, train_y = [], []
test_X, test_y = [], []

# YOUR CODE HERE
data = breast_cancer.data
target = breast_cancer.target

train_X, test_X, train_y, test_y = sklearn.model_selection.train_test_split(
    data, target, test_size=0.2)

# %% [markdown]
# **2.** Trainiert nun eine SVM und ein KNN auf den Trainingsdaten und klassifiziert die Testdaten.

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

model_svm = None
model_knn = None

pred_svm = []
pred_knn = []

# YOUR CODE HERE
model_svm = SVC()
model_knn = KNeighborsClassifier()

model_svm.fit(train_X, train_y)
model_knn.fit(train_X, train_y)

output_svm = model_svm.predict(test_X)
output_knn = model_knn.predict(test_X)

# %% [markdown]
# **3.** Plottet eine verständliche Konfusionsmatrix für beide Modelle. Nutzt hierfür `confusion_matrix` und `ConfusionMatrixDisplay`.
#
# _Hinweis_: vergesst nicht .plot() aufzurufen.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

conf_matr_svm = []
conf_matr_knn = []

# YOUR CODE HERE
conf_matr_svm = confusion_matrix(test_y, output_svm)
conf_matr_knn = confusion_matrix(test_y, output_knn)

display_svm = ConfusionMatrixDisplay(confusion_matrix=conf_matr_svm)
display_svm.plot()

display_knn = ConfusionMatrixDisplay(confusion_matrix=conf_matr_knn)
display_knn.plot()

# %% [markdown]
# **4.** Implementiert die Funktionen `precision` und `recall` für Klasse 1 (`tp = 1`). `cm` steht hierbei für die Konfusionsmatrix.
#
# _Hinweis_: Eure Lösungen werden automatisch getestet. Achtet daher darauf, dass eure Konfusionsmatrizen `conf_matr_svm` und `conf_matr_knn` heißen, wie in **3.** definiert.

# %%
def precision(cm):
    # YOUR CODE HERE
    TP = cm[1, 1]
    FP = cm[0, 1]
    return TP / (TP+FP)

def recall(cm):
    # YOUR CODE HERE
    TP = cm[1, 1]
    FN = cm[1, 0]
    return TP / (TP+FN)

# %%
print(f'''-- SVM Class 1 -- 
    Precision: {precision(conf_matr_svm):.3}, 
    Recall: {recall(conf_matr_svm):.3}''')

print(f'''-- KNN Class 1 -- 
    Precision: {precision(conf_matr_knn):.3}, 
    Recall: {recall(conf_matr_knn):.3}''')

# Euer Ergebnis wird automatisch getestet.
# Out:
# -- SVM Class 1 --
#     Precision: 0.904,
#     Recall: 0.987
# -- KNN Class 1 --
#     Precision: 0.946,
#     Recall: 0.921

# %% [markdown]
# **6.** Ist eine SVM oder ein KNN besser auf dem Breast Cancer Datenset?

# %% [markdown]
# Die Antwort hängt davon ab, ob Precision oder Recall wichtig ist. Wenn es wichtig ist dass die positiven Vorhersagen genau sind und es okay ist, wenn man einige true positives zu verpassen, ist die SVM besser, aber wenn es wichtiger ist, dass möglichst alle true positives gefunden werden, auch wenn das zu einigen false positives führt, ist KNN in diesem Fall besser.

# %% [markdown]
# **7.** Ist ein 80/20 Evaluationssplit geschickt? Welche Alternativen gibt es?

# %% [markdown]
# Man kann natürlich einen anderen Split wählen, aber eine Technik wie die K-Fold Cross Validation ist robuster als ein einfacher Split und macht die Ergebnisse stabiler, indem die Daten in k gleich große Teile aufgeteilt wird und das Modell k-mal trainiert und getestet wird, wobei jedes Mal ein anderer Teil als Testdaten verwendet wird.
